# %%
import os
import sys
import urllib.request
import json

client_id = "Qvhz2CWo5kyg9ajRqc6Z"
client_secret = "qg2gXaXe5Q"
encText = urllib.parse.quote("korea polytechnics")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
    #jsonString = json.dumps(response_body.decode('utf-8'),indent=4)
    #print(jsonString)
    dict = json.loads(response_body.decode('utf-8'))
    print(dict['items'])
    for a in dict['items']:
        print("\n")
        print("title :" + a['title'])
        print("\n")
        print("bloggername :"+ a['bloggername'])
        print("\n")
        print("link : " + a['bloggerlink'])
        print("\n")
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 13 May 2019 17:39:58 +0900",
# "total": 119,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "of <b>Korea</b>_<b>Polytechnics</b>, 한국기술교육대학교 교수 방문",
# "link": "http://wooreedul.blogspot.com/2019/05/former-chairman-of-koreapolytechnics.html",
# "description": "이우영 전 폴리텍대학이사장,Former Chairman of <b>Korea</b>_<b>Polytechnics</b>, 한국기술교육대학교 교수 방문 #이우영 전 #폴리텍대학이사장님,Former #Chairman_of_<b>Korea</b>_<b>Polytechnics</b>,이시며, #한국기술교육대학교... ",
# "bloggername": "김수범의 디스크, 체형교정, 사상체질, 다이어트,통증",
# "bloggerlink": "http://wooreedul.blogspot.com/",
# "postdate": "20190506"
#
# },
# {
# "title": "in 창원폴리텍 Chanwon Campus of <b>Korea Polytechnics</b>",
# "link": "https:\/\/blog.naver.com\/gna2630479?Redirect=Log&logNo=220435099291",
# "description": "#카페새늘_ CAFE-SAENEUL Interior design: G&amp;A건설 Project Year: 2015.07 Location: <b>Korea</b> Polytechnic Ⅶ colleges, Jungang-dong, Seongsan-gu, Changwon-si, <b>Korea</b> Project area: 167.23 sqm Finish: Floor_pvc... ",
# "bloggername": "G&A Architecture",
# "bloggerlink": "https://blog.naver.com/gna2630479",
# "postdate": "20150729"
#
# },
# {
# "title": "한국폴리텍대학(<b>Korea Polytechnics</b>)",
# "link": "https:\/\/blog.naver.com\/sungkyu7906?Redirect=Log&logNo=140188682967",
# "description": "한국폴리텍대학은 고용노동부 산하의 국책특수대학으로 지난 40년간 산업현장에서 필요로 하는 중간기술 인력을 배출해온 공공직업교육기관이다. 현재 산업학사(2년제 전문대학)... ",
# "bloggername": "일상속발견",
# "bloggerlink": "https://blog.naver.com/sungkyu7906",
# "postdate": "20130507"
#
# },
# {
# "title": "한국폴리텍대학 산학협력단(<b>Korea Polytechnics</b>) 홈페이지",
# "link": "https:\/\/blog.naver.com\/intlabcms?Redirect=Log&logNo=220551789284",
# "description": "사용자가 화면을 인지하는 순서를 적극 활용한 디자인으로서 전체적으로 Blue를 아이덴티티 색상으로 활용하여 톤앤매너를 강조하였습니다. [ 한국폴리텍대학 산학협력단 메인 화면 ]",
# "bloggername": "회원맞춤형 경품포털 EVENTPLUS",
# "bloggerlink": "https://blog.naver.com/intlabcms",
# "postdate": "20151127"
#
# },
# {
# "title": "한국 폴리텍대학 광주캠퍼스 기대 이상으로 좋은데요",
# "link": "https:\/\/blog.naver.com\/kkum3975?Redirect=Log&logNo=221508892553",
# "description": "폴리텍대학 (Polytechnics)은 호주, 영국, 독일, 싱가폴 등 세계적으로 &quot;종합기술전문학교&quot;라는 뜻으로 통용되며, 한국폴리텍대학 (<b>Korea Polytechnics</b>)은 새로운 직업교육 패러다임과 미래지향적이며 역동적인 이미지... ",
# "bloggername": "블로그교육 과 다양한 정보공유",
# "bloggerlink": "https://blog.naver.com/kkum3975",
# "postdate": "20190409"
#
# },
# {
# "title": "한국폴리텍 대학 채용 2018년 상반기 한국폴리텍 대학 NCS기반... ",
# "link": "https:\/\/blog.naver.com\/tradepeople?Redirect=Log&logNo=221251942297",
# "description": "영문명이 <b>Korea Polytechnics</b>인데, Polytechnics는 세계적으로 &quot;종합기술전문학교&quot;라는 뜻으로 통용된다. 대학 로고를 보면 <b>KOrea Polytechnics</b>에서 'KOPo'를 형상화한 것이다. 2006년 3월 종래의 기능대학과... ",
# "bloggername": "tradepeople",
# "bloggerlink": "https://blog.naver.com/tradepeople",
# "postdate": "20180413"
#
# },
# {
# "title": "[청년정책] 공시생, 취업길 찾아 새내기로 변신한 사연?",
# "link": "https:\/\/blog.naver.com\/we_are_youth?Redirect=Log&logNo=221128546078",
# "description": "한국폴리텍대학(<b>Korea Polytechnics</b>)은 대한민국을 대표하는 공공직업훈련기관으로서 전국에 35개 캠퍼스를 운영하고 있습니다. 전기, 기계, 자동차 등 제조업의 기본이 되는 뿌리기술부터 4차 산업혁명을... ",
# "bloggername": "청년정책사용설명서!",
# "bloggerlink": "https://blog.naver.com/we_are_youth",
# "postdate": "20171030"
#
# },
# {
# "title": "[인천공항] 영종도 한국폴리텍대학 캠퍼스 추진",
# "link": "https:\/\/blog.naver.com\/yjd-sandglass?Redirect=Log&logNo=221421101323",
# "description": "영종도 한국폴리텍대학 추진 인천공항·폴리텍 '항공전문인력' 키운다 - 인천일보 한국폴리텍대학(<b>Korea Polytechnics</b>)이 항공정비산업(MRO)과 대학을 통합한 산·학융합형의 항공전문가 양성을 목표로... ",
# "bloggername": "운사랑",
# "bloggerlink": "https://blog.naver.com/yjd-sandglass",
# "postdate": "20181217"
#
# },
# {
# "title": "Engineering College <b>Korea</b> Polytechnic VI / Baum Architects",
# "link": "https:\/\/blog.naver.com\/bea1116?Redirect=Log&logNo=220259818004",
# "description": "<b>Korea Polytechnics</b> VI – Engineering College in Gumi Campus is now working as the heart of the campus. © Won Yang Kim The Engineering College is a linear building along the East-West... ",
# "bloggername": "Architecture Design",
# "bloggerlink": "https://blog.naver.com/bea1116",
# "postdate": "20150202"
#
# },
# {
# "title": "한국폴리텍대학교  대한민국  미래산업을  여는... ",
# "link": "https:\/\/blog.naver.com\/hwaseongcampus?Redirect=Log&logNo=221418122634",
# "description": "호주, 영국, 독일, 싱가폴 등 세계적으로 &quot;종합기술전문학교&quot; 라는 뜻으로 통용되며 한국폴리텍대학(<b>korea polytechnics</b>)의 로고는 새로운 직업교육 패러다임과 미래지향적이며 역동적인 이미지 '한국을 대표하는... ",
# "bloggername": "한국폴리텍대학 화성캠퍼스 표면처리학과",
# "bloggerlink": "https://blog.naver.com/hwaseongcampus",
# "postdate": "20181213"
#
# }
# ]
# }
#
# [{'title': 'of <b>Korea</b>_<b>Polytechnics</b>, 한국기술교육대학교 교수 방문', 'link': 'http://wooreedul.blogspot.com/2019/05/former-chairman-of-koreapolytechnics.html', 'description': '이우영 전 폴리텍대학이사장,Former Chairman of <b>Korea</b>_<b>Polytechnics</b>, 한국기술교육대학교 교수 방문 #이우영 전 #폴리텍대학이사장님,Former #Chairman_of_<b>Korea</b>_<b>Polytechnics</b>,이시며, #한국기술교육대학교... ', 'bloggername': '김수범의 디스크, 체형교정, 사상체질, 다이어트,통증', 'bloggerlink': 'http://wooreedul.blogspot.com/', 'postdate': '20190506'}, {'title': 'in 창원폴리텍 Chanwon Campus of <b>Korea Polytechnics</b>', 'link': 'https://blog.naver.com/gna2630479?Redirect=Log&logNo=220435099291', 'description': '#카페새늘_ CAFE-SAENEUL Interior design: G&amp;A건설 Project Year: 2015.07 Location: <b>Korea</b> Polytechnic Ⅶ colleges, Jungang-dong, Seongsan-gu, Changwon-si, <b>Korea</b> Project area: 167.23 sqm Finish: Floor_pvc... ', 'bloggername': 'G&A Architecture', 'bloggerlink': 'https://blog.naver.com/gna2630479', 'postdate': '20150729'}, {'title': '한국폴리텍대학(<b>Korea Polytechnics</b>)', 'link': 'https://blog.naver.com/sungkyu7906?Redirect=Log&logNo=140188682967', 'description': '한국폴리텍대학은 고용노동부 산하의 국책특수대학으로 지난 40년간 산업현장에서 필요로 하는 중간기술 인력을 배출해온 공공직업교육기관이다. 현재 산업학사(2년제 전문대학)... ', 'bloggername': '일상속발견', 'bloggerlink': 'https://blog.naver.com/sungkyu7906', 'postdate': '20130507'}, {'title': '한국폴리텍대학 산학협력단(<b>Korea Polytechnics</b>) 홈페이지', 'link': 'https://blog.naver.com/intlabcms?Redirect=Log&logNo=220551789284', 'description': '사용자가 화면을 인지하는 순서를 적극 활용한 디자인으로서 전체적으로 Blue를 아이덴티티 색상으로 활용하여 톤앤매너를 강조하였습니다. [ 한국폴리텍대학 산학협력단 메인 화면 ]', 'bloggername': '회원맞춤형 경품포털 EVENTPLUS', 'bloggerlink': 'https://blog.naver.com/intlabcms', 'postdate': '20151127'}, {'title': '한국 폴리텍대학 광주캠퍼스 기대 이상으로 좋은데요', 'link': 'https://blog.naver.com/kkum3975?Redirect=Log&logNo=221508892553', 'description': '폴리텍대학 (Polytechnics)은 호주, 영국, 독일, 싱가폴 등 세계적으로 &quot;종합기술전문학교&quot;라는 뜻으로 통용되며, 한국폴리텍대학 (<b>Korea Polytechnics</b>)은 새로운 직업교육 패러다임과 미래지향적이며 역동적인 이미지... ', 'bloggername': '블로그교육 과 다양한 정보공유', 'bloggerlink': 'https://blog.naver.com/kkum3975', 'postdate': '20190409'}, {'title': '한국폴리텍 대학 채용 2018년 상반기 한국폴리텍 대학 NCS기반... ', 'link': 'https://blog.naver.com/tradepeople?Redirect=Log&logNo=221251942297', 'description': "영문명이 <b>Korea Polytechnics</b>인데, Polytechnics는 세계적으로 &quot;종합기술전문학교&quot;라는 뜻으로 통용된다. 대학 로고를 보면 <b>KOrea Polytechnics</b>에서 'KOPo'를 형상화한 것이다. 2006년 3월 종래의 기능대학과... ", 'bloggername': 'tradepeople', 'bloggerlink': 'https://blog.naver.com/tradepeople', 'postdate': '20180413'}, {'title': '[청년정책] 공시생, 취업길 찾아 새내기로 변신한 사연?', 'link': 'https://blog.naver.com/we_are_youth?Redirect=Log&logNo=221128546078', 'description': '한국폴리텍대학(<b>Korea Polytechnics</b>)은 대한민국을 대표하는 공공직업훈련기관으로서 전국에 35개 캠퍼스를 운영하고 있습니다. 전기, 기계, 자동차 등 제조업의 기본이 되는 뿌리기술부터 4차 산업혁명을... ', 'bloggername': '청년정책사용설명서!', 'bloggerlink': 'https://blog.naver.com/we_are_youth', 'postdate': '20171030'}, {'title': '[인천공항] 영종도 한국폴리텍대학 캠퍼스 추진', 'link': 'https://blog.naver.com/yjd-sandglass?Redirect=Log&logNo=221421101323', 'description': "영종도 한국폴리텍대학 추진 인천공항·폴리텍 '항공전문인력' 키운다 - 인천일보 한국폴리텍대학(<b>Korea Polytechnics</b>)이 항공정비산업(MRO)과 대학을 통합한 산·학융합형의 항공전문가 양성을 목표로... ", 'bloggername': '운사랑', 'bloggerlink': 'https://blog.naver.com/yjd-sandglass', 'postdate': '20181217'}, {'title': 'Engineering College <b>Korea</b> Polytechnic VI / Baum Architects', 'link': 'https://blog.naver.com/bea1116?Redirect=Log&logNo=220259818004', 'description': '<b>Korea Polytechnics</b> VI – Engineering College in Gumi Campus is now working as the heart of the campus. © Won Yang Kim The Engineering College is a linear building along the East-West... ', 'bloggername': 'Architecture Design', 'bloggerlink': 'https://blog.naver.com/bea1116', 'postdate': '20150202'}, {'title': '한국폴리텍대학교  대한민국  미래산업을  여는... ', 'link': 'https://blog.naver.com/hwaseongcampus?Redirect=Log&logNo=221418122634', 'description': "호주, 영국, 독일, 싱가폴 등 세계적으로 &quot;종합기술전문학교&quot; 라는 뜻으로 통용되며 한국폴리텍대학(<b>korea polytechnics</b>)의 로고는 새로운 직업교육 패러다임과 미래지향적이며 역동적인 이미지 '한국을 대표하는... ", ' ...
#
#
# title :of <b>Korea</b>_<b>Polytechnics</b>, 한국기술교육대학교 교수 방문
#
#
# bloggername :김수범의 디스크, 체형교정, 사상체질, 다이어트,통증
#
#
# link : http://wooreedul.blogspot.com/
#
#
#
#
# title :in 창원폴리텍 Chanwon Campus of <b>Korea Polytechnics</b>
#
#
# bloggername :G&A Architecture
#
#
# link : https://blog.naver.com/gna2630479
#
#
#
#
# title :한국폴리텍대학(<b>Korea Polytechnics</b>)
#
#
# bloggername :일상속발견
#
#
# link : https://blog.naver.com/sungkyu7906
#
#
#
#
# title :한국폴리텍대학 산학협력단(<b>Korea Polytechnics</b>) 홈페이지
#
#
# bloggername :회원맞춤형 경품포털 EVENTPLUS
#
#
# link : https://blog.naver.com/intlabcms
#
#
#
#
# title :한국 폴리텍대학 광주캠퍼스 기대 이상으로 좋은데요
#
#
# bloggername :블로그교육 과 다양한 정보공유
#
#
# link : https://blog.naver.com/kkum3975
#
#
#
#
# title :한국폴리텍 대학 채용 2018년 상반기 한국폴리텍 대학 NCS기반...
#
#
# bloggername :tradepeople
#
#
# link : https://blog.naver.com/tradepeople
#
#
#
#
# title :[청년정책] 공시생, 취업길 찾아 새내기로 변신한 사연?
#
#
# bloggername :청년정책사용설명서!
#
#
# link : https://blog.naver.com/we_are_youth
#
#
#
#
# title :[인천공항] 영종도 한국폴리텍대학 캠퍼스 추진
#
#
# bloggername :운사랑
#
#
# link : https://blog.naver.com/yjd-sandglass
#
#
#
#
# title :Engineering College <b>Korea</b> Polytechnic VI / Baum Architects
#
#
# bloggername :Architecture Design
#
#
# link : https://blog.naver.com/bea1116
#
#
#
#
# title :한국폴리텍대학교  대한민국  미래산업을  여는...
#
#
# bloggername :한국폴리텍대학 화성캠퍼스 표면처리학과
#
#
# link : https://blog.naver.com/hwaseongcampus
