# %% [markdown]
# ### csv to image 파일 변환

# %%
#! /usr/bin/env python3
# -*-coding: utf-8-*-

__author__ = 'Moonkie'

import numpy as np
import cv2
import mxnet as mx
import pandas as pd
import random
import os

#curdir = os.path.abspath(os.path.dirname(__file__))
curdir = "../images/realtime/input/"

def gen_record(csvfile,channel):
    data = pd.read_csv(csvfile,delimiter=',',dtype='a')
    labels = np.array(data['emotion'],np.float)
    # print(labels,'\n',data['emotion'])
        
    imagebuffer = np.array(data['pixels'])
    images = np.array([np.fromstring(image,np.uint8,sep=' ') for image in imagebuffer])
    del imagebuffer
    num_shape = int(np.sqrt(images.shape[-1]))
    images.shape = (images.shape[0],num_shape,num_shape)
    # img=images[0];cv2.imshow('test',img);cv2.waitKey(0);cv2.destroyAllWindow();exit()
    dirs = set(data['Usage'])
    subdirs = set(labels)
    class_dir = {}
    for dr in dirs:
        dest = os.path.join(curdir,dr)
        class_dir[dr] = dest
        if not os.path.exists(dest):
            os.mkdir(dest)
            
    data = zip(labels,images,data['Usage'])
    
    for d in data:
        destdir = os.path.join(class_dir[d[-1]],str(int(d[0])))
        if not os.path.exists(destdir):
            os.mkdir(destdir)
        img = d[1]
        filepath = unique_name(destdir,d[-1])
        print('Save image to %s' % filepath)
        if not filepath:
            continue
        sig = cv2.imwrite(filepath,img)
        if not sig:
            print('Error')
            exit(-1)


def unique_name(pardir,prefix,suffix='jpg'):
    filename = '{0}_{1}.{2}'.format(prefix,random.randint(1,10**8),suffix)
    filepath = os.path.join(pardir,filename)
    if not os.path.exists(filepath):
        return filepath
    unique_name(pardir,prefix,suffix)
    


if __name__ == '__main__':
    filename = 'fer2013.csv'
    filename = os.path.join(curdir,filename)
    gen_record(filename,1)
    
    # ##################### test
    # tmp = unique_name('./Training','Training')
    # print(tmp)
# Out:
# Save image to ../images/realtime/input/Training\0\Training_445857.jpg
# Save image to ../images/realtime/input/Training\0\Training_87306005.jpg
# Save image to ../images/realtime/input/Training\2\Training_79438126.jpg
# Save image to ../images/realtime/input/Training\4\Training_2094560.jpg
# Save image to ../images/realtime/input/Training\6\Training_65347422.jpg
# Save image to ../images/realtime/input/Training\2\Training_32956818.jpg
# Save image to ../images/realtime/input/Training\4\Training_8695584.jpg
# Save image to ../images/realtime/input/Training\3\Training_29537757.jpg
# Save image to ../images/realtime/input/Training\3\Training_91891467.jpg
# Save image to ../images/realtime/input/Training\2\Training_89192565.jpg
# Save image to ../images/realtime/input/Training\0\Training_51088112.jpg
# Save image to ../images/realtime/input/Training\6\Training_23941968.jpg
# Save image to ../images/realtime/input/Training\6\Training_49038954.jpg
# Save image to ../images/realtime/input/Training\6\Training_33167974.jpg
# Save image to ../images/realtime/input/Training\3\Training_56121514.jpg
# Save image to ../images/realtime/input/Training\5\Training_64715352.jpg
# Save image to ../images/realtime/input/Training\3\Training_27123897.jpg
# Save image to ../images/realtime/input/Training\2\Training_40108492.jpg
# Save image to ../images/realtime/input/Training\6\Training_77125538.jpg
# Save image to ../images/realtime/input/Training\4\Training_22972820.jpg
# Save image to ../images/realtime/input/Training\4\Training_30602474.jpg
# Save image to ../images/realtime/input/Training\2\Training_42647937.jpg
# Save image to ../images/realtime/input/Training\0\Training_54082875.jpg
# Save image to ../images/realtime/input/Training\0\Training_31147011.jpg
# Save image to ../images/realtime/input/Training\3\Training_77181322.jpg
# Save image to ../images/realtime/input/Training\3\Training_79086254.jpg
# Save image to ../images/realtime/input/Training\5\Training_17617479.jpg
# Save image to ../images/realtime/input/Training\0\Training_10319414.jpg
# Save image to ../images/realtime/input/Training\3\Training_88425378.jpg
# Save image to ../images/realtime/input/Training\5\Training_5095290.jpg
# Save image to ../images/realtime/input/Training\3\Training_90124164.jpg
# Save image to ../images/realtime/input/Training\6\Training_29289570.jpg
# Save image to ../images/realtime/input/Training\3\Training_11352043.jpg
# Save image to ../images/realtime/input/Training\2\Training_9770002.jpg
# Save image to ../images/realtime/input/Training\3\Training_31786313.jpg
# Save image to ../images/realtime/input/Training\6\Training_51502332.jpg
# Save image to ../images/realtime/input/Training\6\Training_53630638.jpg
# Save image to ../images/realtime/input/Training\6\Training_4182970.jpg
# Save image to ../images/realtime/input/Training\0\Training_59756957.jpg
# Save image to ../images/realtime/input/Training\5\Training_24275837.jpg
# Save image to ../images/realtime/input/Training\0\Training_92504502.jpg
# Save image to ../images/realtime/input/Training\3\Training_35119720.jpg
# Save image to ../images/realtime/input/Training\4\Training_10959071.jpg
# Save image to ../images/realtime/input/Training\0\Training_8850774.jpg
# Save image to ../images/realtime/input/Training\6\Training_59393549.jpg
# Save image to ../images/realtime/input/Training\2\Training_11058386.jpg
# Save image to ../images/realtime/input/Training\3\Training_95073623.jpg
# Save image to ../images/realtime/input/Training\6\Training_90043.jpg
# Save image to ../images/realtime/input/Training\2\Training_21258868.jpg
# Save image to ../images/realtime/input/Training\2\Training_76308638.jpg
# Save image to ../images/realtime/input/Training\2\Training_88666755.jpg
# Save image to ../images/realtime/input/Training\5\Training_57534819.jpg
# Save image to ../images/realtime/input/Training\5\Training_1339816.jpg
# Save image to ../images/realtime/input/Training\6\Training_73965409.jpg
# Save image to ../images/realtime/input/Training\4\Training_10132814.jpg
# Save image to ../images/realtime/input/Training\5\Training_88159365.jpg
# Save image to ../images/realtime/input/Training\0\Training_41244285.jpg
# Save image to ../images/realtime/input/Training\3\Training_24874491.jpg
# Save image to ../images/realtime/input/Training\4\Training_85222683.jpg
# Save image to ../images/realtime/input/Training\2\Training_4358046.jpg
# Save image to ../images/realtime/input/Training\6\Training_39853274.jpg
# Save image to ../images/realtime/input/Training\5\Training_37863159.jpg
# Save image to ../images/realtime/input/Training\3\Training_39585188.jpg
# Save image to ../images/realtime/input/Training\4\Training_25707338.jpg
# Save image to ../images/realtime/input/Training\3\Training_25585700.jpg
# Save image to ../images/realtime/input/Training\0\Training_2400092.jpg
# Save image to ../images/realtime/input/Training\4\Training_57607622.jpg
# Save image to ../images/realtime/input/Training\3\Training_98676447.jpg
# Save image to ../images/realtime/input/Training\0\Training_74295457.jpg
# Save image to ../images/realtime/input/Training\5\Training_72017977.jpg
# Save image to ../images/realtime/input/Training\4\Training_12640450.jpg
# Save image to ../images/realtime/input/Training\2\Training_63578934.jpg
# Save image to ../images/realtime/input/Training\4\Training_28182437.jpg
# Save image to ../images/realtime/input/Training\2\Training_16222837.jpg
# Save image to ../images/realtime/input/Training\0\Training_47387440.jpg
# Save image to ../images/realtime/input/Training\6\Training_13924624.jpg
# Save image to ../images/realtime/input/Training\0\Training_33037499.jpg
# Save image to ../images/realtime/input/Training\0\Training_9462398.jpg
# Save image to ../images/realtime/input/Training\5\Training_95461941.jpg
# Save image to ../images/realtime/input/Training\4\Training_18082651.jpg
# Save image to ../images/realtime/input/Training\3\Training_53156226.jpg
# Save image to ../images/realtime/input/Training\5\Training_6465075.jpg
# Save image to ../images/realtime/input/Training\3\Training_12858706.jpg
# Save image to ../images/realtime/input/Training\6\Training_52659672.jpg
# Save image to ../images/realtime/input/Training\2\Training_87167264.jpg
# Save image to ../images/realtime/input/Training\2\Training_21640538.jpg
# Save image to ../images/realtime/input/Training\4\Training_59773693.jpg
# Save image to ../images/realtime/input/Training\4\Training_74929734.jpg
# Save image to ../images/realtime/input/Training\5\Training_48053163.jpg
# Save image to ../images/realtime/input/Training\4\Training_94188753.jpg
# Save image to ../images/realtime/input/Training\0\Training_55865382.jpg
# Save image to ../images/realtime/input/Training\0\Training_70266546.jpg
# Save image to ../images/realtime/input/Training\6\Training_5718211.jpg
# Save image to ../images/realtime/input/Training\0\Training_95158533.jpg
# Save image to ../images/realtime/input/Training\6\Training_37518343.jpg
# Save image to ../images/realtime/input/Training\2\Training_14969999.jpg
# Save image to ../images/realtime/input/Training\2\Training_66527095.jpg
# Save image to ../images/realtime/input/Training\3\Training_68210989.jpg
# Save image to ../images/realtime/input/Training\4\Training_91528495.jpg
# Save image to ../images/realtime/input/Training\3\Training_84371941.jpg
# Save image to ../images/realtime/input/Training\3\Training_70571518.jpg
# Save image to ../images/realtime/input/Training\2\Training_73298752.jpg
# Save image to ../images/realtime/input/Training\6\Training_81473064.jpg
# Save image to ../images/realtime/input/Training\3\Training_3900040.jpg
# Save image to ../images/realtime/input/Training\4\Training_92870385.jpg
# Save image to ../images/realtime/input/Training\3\Training_98474091.jpg
# Save image to ../images/realtime/input/Training\2\Training_75014622.jpg
# Save image to ../images/realtime/input/Training\0\Training_4740177.jpg
# Save image to ../images/realtime/input/Training\2\Training_82263597.jpg
# Save image to ../images/realtime/input/Training\3\Training_35924477.jpg
# Save image to ../images/realtime/input/Training\2\Training_74704707.jpg
# Save image to ../images/realtime/input/Training\3\Training_57103391.jpg
# Save image to ../images/realtime/input/Training\6\Training_17324928.jpg
# Save image to ../images/realtime/input/Training\6\Training_24215706.jpg
# Save image to ../images/realtime/input/Training\3\Training_85975652.jpg
# Save image to ../images/realtime/input/Training\4\Training_5085211.jpg
# Save image to ../images/realtime/input/Training\4\Training_46724717.jpg
# Save image to ../images/realtime/input/Training\0\Training_68965340.jpg
# Save image to ../images/realtime/input/Training\3\Training_82030884.jpg
# Save image to ../images/realtime/input/Training\3\Training_45523123.jpg
# Save image to ../images/realtime/input/Training\0\Training_25879415.jpg
# Save image to ../images/realtime/input/Training\2\Training_73046766.jpg
# Save image to ../images/realtime/input/Training\0\Training_5942315.jpg
# Save image to ../images/realtime/input/Training\0\Training_88259756.jpg
# Save image to ../images/realtime/input/Training\3\Training_98665501.jpg
# Save image to ../images/realtime/input/Training\3\Training_45242761.jpg
# Save image to ../images/realtime/input/Training\0\Training_70133296.jpg
# Save image to ../images/realtime/input/Training\4\Training_45299457.jpg
# Save image to ../images/realtime/input/Training\5\Training_70965068.jpg
# Save image to ../images/realtime/input/Training\2\Training_10057712.jpg
# Save image to ../images/realtime/input/Training\4\Training_23794063.jpg
# Save image to ../images/realtime/input/Training\2\Training_21870106.jpg
# Save image to ../images/realtime/input/Training\5\Training_88370390.jpg
# Save image to ../images/realtime/input/Training\3\Training_88342308.jpg
# Save image to ../images/realtime/input/Training\0\Training_75143503.jpg
# Save image to ../images/realtime/input/Training\6\Training_24505821.jpg
# Save image to ../images/realtime/input/Training\6\Training_28020368.jpg
# Save image to ../images/realtime/input/Training\2\Training_4620775.jpg
# Save image to ../images/realtime/input/Training\2\Training_42223387.jpg
# Save image to ../images/realtime/input/Training\3\Training_50426685.jpg
# Save image to ../images/realtime/input/Training\2\Training_81769208.jpg
# Save image to ../images/realtime/input/Training\3\Training_61894497.jpg
# Save image to ../images/realtime/input/Training\3\Training_2754715.jpg
# Save image to ../images/realtime/input/Training\3\Training_32462407.jpg
# Save image to ../images/realtime/input/Training\3\Training_7653937.jpg
# Save image to ../images/realtime/input/Training\3\Training_18326339.jpg
# Save image to ../images/realtime/input/Training\4\Training_3332176.jpg
# Save image to ../images/realtime/input/Training\2\Training_5830102.jpg
# Save image to ../images/realtime/input/Training\2\Training_6528886.jpg
# Save image to ../images/realtime/input/Training\0\Training_51059602.jpg
# Save image to ../images/realtime/input/Training\0\Training_61679169.jpg
# Save image to ../images/realtime/input/Training\2\Training_94621601.jpg
# Save image to ../images/realtime/input/Training\6\Training_4698689.jpg
# Save image to ../images/realtime/input/Training\3\Training_26828572.jpg
# Save image to ../images/realtime/input/Training\4\Training_91619276.jpg
# Save image to ../images/realtime/input/Training\5\Training_4856658.jpg
# Save image to ../images/realtime/input/Training\3\Training_82870900.jpg
# Save image to ../images/realtime/input/Training\0\Training_76576957.jpg
# Save image to ../images/realtime/input/Training\2\Training_56547129.jpg
# Save image to ../images/realtime/input/Training\4\Training_46821752.jpg
# Save image to ../images/realtime/input/Training\5\Training_5442610.jpg
# Save image to ../images/realtime/input/Training\2\Training_51907125.jpg
# Save image to ../images/realtime/input/Training\3\Training_37215155.jpg
# Save image to ../images/realtime/input/Training\4\Training_53319153.jpg
# Save image to ../images/realtime/input/Training\6\Training_65423610.jpg
# Save image to ../images/realtime/input/Training\3\Training_92846428.jpg
# Save image to ../images/realtime/input/Training\4\Training_85614916.jpg
# Save image to ../images/realtime/input/Training\3\Training_28616434.jpg
# Save image to ../images/realtime/input/Training\6\Training_57439377.jpg
# Save image to ../images/realtime/input/Training\0\Training_50585642.jpg
# Save image to ../images/realtime/input/Training\4\Training_5422224.jpg
# Save image to ../images/realtime/input/Training\4\Training_92713537.jpg
# Save image to ../images/realtime/input/Training\4\Training_90158233.jpg
# Save image to ../images/realtime/input/Training\2\Training_89655485.jpg
# Save image to ../images/realtime/input/Training\6\Training_16625606.jpg
# Save image to ../images/realtime/input/Training\5\Training_23122341.jpg
# Save image to ../images/realtime/input/Training\5\Training_47092164.jpg
# Save image to ../images/realtime/input/Training\6\Training_68124101.jpg
# Save image to ../images/realtime/input/Training\5\Training_1256397.jpg
# Save image to ../images/realtime/input/Training\2\Training_42864713.jpg
# Save image to ../images/realtime/input/Training\3\Training_79523283.jpg
# Save image to ../images/realtime/input/Training\2\Training_44659418.jpg
# Save image to ../images/realtime/input/Training\3\Training_86247738.jpg
# Save image to ../images/realtime/input/Training\4\Training_95706814.jpg
# Save image to ../images/realtime/input/Training\0\Training_8076284.jpg
# Save image to ../images/realtime/input/Training\2\Training_56687044.jpg
# Save image to ../images/realtime/input/Training\0\Training_55281746.jpg
# Save image to ../images/realtime/input/Training\3\Training_91385186.jpg
# Save image to ../images/realtime/input/Training\0\Training_86176526.jpg
# Save image to ../images/realtime/input/Training\2\Training_41515180.jpg
# Save image to ../images/realtime/input/Training\2\Training_80253689.jpg
# Save image to ../images/realtime/input/Training\5\Training_46736070.jpg
# Save image to ../images/realtime/input/Training\3\Training_68028565.jpg
# Save image to ../images/realtime/input/Training\5\Training_86812668.jpg
# Save image to ../images/realtime/input/Training\5\Training_65847689.jpg
# Save image to ../images/realtime/input/Training\4\Training_40307862.jpg
# Save image to ../images/realtime/input/Training\3\Training_79601889.jpg
# Save image to ../images/realtime/input/Training\0\Training_73782472.jpg
# Save image to ../images/realtime/input/Training\6\Training_35088657.jpg
# Save image to ../images/realtime/input/Training\5\Training_72714297.jpg
# Save image to ../images/realtime/input/Training\2\Training_96835609.jpg
# Save image to ../images/realtime/input/Training\6\Training_6210384.jpg
# Save image to ../images/realtime/input/Training\0\Training_37588979.jpg
# Save image to ../images/realtime/input/Training\0\Training_15918661.jpg
# Save image to ../images/realtime/input/Training\4\Training_51475188.jpg
# Save image to ../images/realtime/input/Training\5\Training_59302098.jpg
# Save image to ../images/realtime/input/Training\6\Training_11742896.jpg
# Save image to ../images/realtime/input/Training\3\Training_2097800.jpg
# Save image to ../images/realtime/input/Training\5\Training_24721478.jpg
# Save image to ../images/realtime/input/Training\5\Training_73696742.jpg
# Save image to ../images/realtime/input/Training\3\Training_92969310.jpg
# Save image to ../images/realtime/input/Training\2\Training_87596694.jpg
# Save image to ../images/realtime/input/Training\2\Training_32641472.jpg
# Save image to ../images/realtime/input/Training\3\Training_9161542.jpg
# Save image to ../images/realtime/input/Training\3\Training_32041713.jpg
# Save image to ../images/realtime/input/Training\3\Training_3973792.jpg
# Save image to ../images/realtime/input/Training\3\Training_69689345.jpg
# Save image to ../images/realtime/input/Training\6\Training_6214684.jpg
# Save image to ../images/realtime/input/Training\3\Training_33239498.jpg
# Save image to ../images/realtime/input/Training\6\Training_39065504.jpg
# Save image to ../images/realtime/input/Training\3\Training_84941.jpg
# Save image to ../images/realtime/input/Training\0\Training_30027730.jpg
# Save image to ../images/realtime/input/Training\6\Training_7386531.jpg
# Save image to ../images/realtime/input/Training\3\Training_83564104.jpg
# Save image to ../images/realtime/input/Training\2\Training_65010140.jpg
# Save image to ../images/realtime/input/Training\0\Training_36467990.jpg
# Save image to ../images/realtime/input/Training\6\Training_95983228.jpg
# Save image to ../images/realtime/input/Training\5\Training_31945947.jpg
# Save image to ../images/realtime/input/Training\6\Training_14725625.jpg
# Save image to ../images/realtime/input/Training\0\Training_29140840.jpg
# Save image to ../images/realtime/input/Training\5\Training_59407766.jpg
# Save image to ../images/realtime/input/Training\4\Training_48459910.jpg
# Save image to ../images/realtime/input/Training\3\Training_34208787.jpg
# Save image to ../images/realtime/input/Training\0\Training_84670572.jpg
# Save image to ../images/realtime/input/Training\3\Training_21969031.jpg
# Save image to ../images/realtime/input/Training\0\Training_54503103.jpg
# Save image to ../images/realtime/input/Training\4\Training_38989801.jpg
# Save image to ../images/realtime/input/Training\5\Training_66109833.jpg
# Save image to ../images/realtime/input/Training\4\Training_98049397.jpg
# Save image to ../images/realtime/input/Training\3\Training_51150793.jpg
# Save image to ../images/realtime/input/Training\3\Training_47056213.jpg
# Save image to ../images/realtime/input/Training\0\Training_79339872.jpg
# Save image to ../images/realtime/input/Training\0\Training_93662790.jpg
# Save image to ../images/realtime/input/Training\6\Training_83006255.jpg
# Save image to ../images/realtime/input/Training\2\Training_26448392.jpg
# Save image to ../images/realtime/input/Training\0\Training_29033786.jpg
# Save image to ../images/realtime/input/Training\6\Training_78061139.jpg
# Save image to ../images/realtime/input/Training\3\Training_23789937.jpg
# Save image to ../images/realtime/input/Training\0\Training_13812889.jpg
# Save image to ../images/realtime/input/Training\0\Training_49125375.jpg
# Save image to ../images/realtime/input/Training\6\Training_40987513.jpg
# Save image to ../images/realtime/input/Training\0\Training_93110610.jpg
# Save image to ../images/realtime/input/Training\5\Training_59734465.jpg
# Save image to ../images/realtime/input/Training\6\Training_3307065.jpg
# Save image to ../images/realtime/input/Training\3\Training_6075873.jpg
# Save image to ../images/realtime/input/Training\2\Training_26668899.jpg
# Save image to ../images/realtime/input/Training\5\Training_99495257.jpg
# Save image to ../images/realtime/input/Training\5\Training_17174359.jpg
# Save image to ../images/realtime/input/Training\2\Training_57770122.jpg
# Save image to ../images/realtime/input/Training\0\Training_95356421.jpg
# Save image to ../images/realtime/input/Training\2\Training_11247437.jpg
# Save image to ../images/realtime/input/Training\6\Training_63555003.jpg
# Save image to ../images/realtime/input/Training\6\Training_47989260.jpg
# Save image to ../images/realtime/input/Training\0\Training_9559354.jpg
# Save image to ../images/realtime/input/Training\2\Training_41169254.jpg
# Save image to ../images/realtime/input/Training\3\Training_43313001.jpg
# Save image to ../images/realtime/input/Training\4\Training_80955187.jpg
# Save image to ../images/realtime/input/Training\2\Training_56895633.jpg
# Save image to ../images/realtime/input/Training\6\Training_55762951.jpg
# Save image to ../images/realtime/input/Training\5\Training_78446326.jpg
# Save image to ../images/realtime/input/Training\2\Training_72148187.jpg
# Save image to ../images/realtime/input/Training\2\Training_33679630.jpg
# Save image to ../images/realtime/input/Training\6\Training_77157269.jpg
# Save image to ../images/realtime/input/Training\6\Training_34253448.jpg
# Save image to ../images/realtime/input/Training\6\Training_78841526.jpg
# Save image to ../images/realtime/input/Training\2\Training_85210544.jpg
# Save image to ../images/realtime/input/Training\5\Training_87874584.jpg
# Save image to ../images/realtime/input/Training\3\Training_78451912.jpg
# Save image to ../images/realtime/input/Training\0\Training_28036577.jpg
# Save image to ../images/realtime/input/Training\5\Training_5288411.jpg
# Save image to ../images/realtime/input/Training\0\Training_48668715.jpg
# Save image to ../images/realtime/input/Training\4\Training_32592664.jpg
# Save image to ../images/realtime/input/Training\3\Training_42971101.jpg
# Save image to ../images/realtime/input/Training\3\Training_74077600.jpg
# Save image to ../images/realtime/input/Training\3\Training_39389549.jpg
# Save image to ../images/realtime/input/Training\3\Training_71772612.jpg
# Save image to ../images/realtime/input/Training\6\Training_63933311.jpg
# Save image to ../images/realtime/input/Training\3\Training_12871715.jpg
# Save image to ../images/realtime/input/Training\2\Training_30070674.jpg
# Save image to ../images/realtime/input/Training\4\Training_50202627.jpg
# Save image to ../images/realtime/input/Training\6\Training_18642878.jpg
# Save image to ../images/realtime/input/Training\3\Training_61421482.jpg
# Save image to ../images/realtime/input/Training\2\Training_61888253.jpg
# Save image to ../images/realtime/input/Training\4\Training_27117962.jpg
# Save image to ../images/realtime/input/Training\0\Training_53437389.jpg
# Save image to ../images/realtime/input/Training\0\Training_59191741.jpg
# Save image to ../images/realtime/input/Training\3\Training_91688638.jpg
# Save image to ../images/realtime/input/Training\2\Training_61519701.jpg
# Save image to ../images/realtime/input/Training\0\Training_85371289.jpg
# Save image to ../images/realtime/input/Training\1\Training_29033171.jpg
# Save image to ../images/realtime/input/Training\2\Training_64676193.jpg
# Save image to ../images/realtime/input/Training\2\Training_13345565.jpg
# Save image to ../images/realtime/input/Training\5\Training_32981501.jpg
# Save image to ../images/realtime/input/Training\3\Training_52834723.jpg
# Save image to ../images/realtime/input/Training\5\Training_18818913.jpg
# Save image to ../images/realtime/input/Training\4\Training_13720238.jpg
# Save image to ../images/realtime/input/Training\4\Training_70724201.jpg
# Save image to ../images/realtime/input/Training\0\Training_86055832.jpg
# Save image to ../images/realtime/input/Training\2\Training_79132183.jpg
# Save image to ../images/realtime/input/Training\3\Training_32396034.jpg
# Save image to ../images/realtime/input/Training\4\Training_73078960.jpg
# Save image to ../images/realtime/input/Training\6\Training_27656069.jpg
# Save image to ../images/realtime/input/Training\4\Training_26447727.jpg
# Save image to ../images/realtime/input/Training\2\Training_99489551.jpg
# Save image to ../images/realtime/input/Training\2\Training_96793151.jpg
# Save image to ../images/realtime/input/Training\3\Training_58202038.jpg
# Save image to ../images/realtime/input/Training\5\Training_36300810.jpg
# Save image to ../images/realtime/input/Training\4\Training_47229474.jpg
# Save image to ../images/realtime/input/Training\4\Training_75207231.jpg
# Save image to ../images/realtime/input/Training\5\Training_61235099.jpg
# Save image to ../images/realtime/input/Training\6\Training_99640712.jpg
# Save image to ../images/realtime/input/Training\4\Training_32474280.jpg
# Save image to ../images/realtime/input/Training\5\Training_11156237.jpg
# Save image to ../images/realtime/input/Training\0\Training_33279317.jpg
# Save image to ../images/realtime/input/Training\3\Training_73650532.jpg
# Save image to ../images/realtime/input/Training\3\Training_46057059.jpg
# Save image to ../images/realtime/input/Training\3\Training_3107265.jpg
# Save image to ../images/realtime/input/Training\2\Training_23021605.jpg
# Save image to ../images/realtime/input/Training\5\Training_99658068.jpg
# Save image to ../images/realtime/input/Training\5\Training_16497171.jpg
# Save image to ../images/realtime/input/Training\5\Training_23249985.jpg
# Save image to ../images/realtime/input/Training\3\Training_29399780.jpg
# Save image to ../images/realtime/input/Training\5\Training_71520848.jpg
# Save image to ../images/realtime/input/Training\3\Training_67585111.jpg
# Save image to ../images/realtime/input/Training\3\Training_67200823.jpg
# Save image to ../images/realtime/input/Training\3\Training_33261534.jpg
# Save image to ../images/realtime/input/Training\5\Training_88218094.jpg
# Save image to ../images/realtime/input/Training\6\Training_14118057.jpg
# Save image to ../images/realtime/input/Training\0\Training_30212232.jpg
# Save image to ../images/realtime/input/Training\4\Training_47167651.jpg
# Save image to ../images/realtime/input/Training\2\Training_58007521.jpg
# Save image to ../images/realtime/input/Training\2\Training_92876044.jpg
# Save image to ../images/realtime/input/Training\0\Training_22406687.jpg
# Save image to ../images/realtime/input/Training\4\Training_28222639.jpg
# Save image to ../images/realtime/input/Training\5\Training_59191292.jpg
# Save image to ../images/realtime/input/Training\5\Training_59914527.jpg
# Save image to ../images/realtime/input/Training\6\Training_96171413.jpg
# Save image to ../images/realtime/input/Training\6\Training_21525663.jpg
# Save image to ../images/realtime/input/Training\3\Training_27711270.jpg
# Save image to ../images/realtime/input/Training\2\Training_22992710.jpg
# Save image to ../images/realtime/input/Training\4\Training_58166114.jpg
# Save image to ../images/realtime/input/Training\2\Training_53062369.jpg
# Save image to ../images/realtime/input/Training\4\Training_74145079.jpg
# Save image to ../images/realtime/input/Training\0\Training_91631365.jpg
# Save image to ../images/realtime/input/Training\5\Training_52408728.jpg
# Save image to ../images/realtime/input/Training\0\Training_4398413.jpg
# Save image to ../images/realtime/input/Training\3\Training_66394702.jpg
# Save image to ../images/realtime/input/Training\5\Training_46801363.jpg
# Save image to ../images/realtime/input/Training\2\Training_45218470.jpg
# Save image to ../images/realtime/input/Training\4\Training_89051631.jpg
# Save image to ../images/realtime/input/Training\0\Training_4037725.jpg
# Save image to ../images/realtime/input/Training\4\Training_14937618.jpg
# Save image to ../images/realtime/input/Training\5\Training_59566228.jpg
# Save image to ../images/realtime/input/Training\6\Training_99733135.jpg
# Save image to ../images/realtime/input/Training\3\Training_81422002.jpg
# Save image to ../images/realtime/input/Training\2\Training_55774319.jpg
# Save image to ../images/realtime/input/Training\3\Training_39716480.jpg
# Save image to ../images/realtime/input/Training\5\Training_66385590.jpg
# Save image to ../images/realtime/input/Training\0\Training_2123327.jpg
# Save image to ../images/realtime/input/Training\0\Training_47711646.jpg
# Save image to ../images/realtime/input/Training\3\Training_52427846.jpg
# Save image to ../images/realtime/input/Training\3\Training_11914899.jpg
# Save image to ../images/realtime/input/Training\2\Training_93199689.jpg
# Save image to ../images/realtime/input/Training\6\Training_6165410.jpg
# Save image to ../images/realtime/input/Training\0\Training_46774371.jpg
# Save image to ../images/realtime/input/Training\2\Training_5924738.jpg
# Save image to ../images/realtime/input/Training\6\Training_46413706.jpg
# Save image to ../images/realtime/input/Training\0\Training_31764577.jpg
# Save image to ../images/realtime/input/Training\3\Training_83106290.jpg
# Save image to ../images/realtime/input/Training\2\Training_3032369.jpg
# Save image to ../images/realtime/input/Training\3\Training_38801713.jpg
# Save image to ../images/realtime/input/Training\2\Training_883708.jpg
# Save image to ../images/realtime/input/Training\6\Training_1810974.jpg
# Save image to ../images/realtime/input/Training\4\Training_17194898.jpg
# Save image to ../images/realtime/input/Training\3\Training_32403935.jpg
# Save image to ../images/realtime/input/Training\4\Training_62786758.jpg
# Save image to ../images/realtime/input/Training\4\Training_59694345.jpg
# Save image to ../images/realtime/input/Training\0\Training_10332289.jpg
# Save image to ../images/realtime/input/Training\1\Training_637421.jpg
# Save image to ../images/realtime/input/Training\2\Training_11442460.jpg
# Save image to ../images/realtime/input/Training\4\Training_29821927.jpg
# Save image to ../images/realtime/input/Training\6\Training_50742306.jpg
# Save image to ../images/realtime/input/Training\5\Training_21162681.jpg
# Save image to ../images/realtime/input/Training\0\Training_68842783.jpg
# Save image to ../images/realtime/input/Training\4\Training_55122041.jpg
# Save image to ../images/realtime/input/Training\6\Training_52141486.jpg
# Save image to ../images/realtime/input/Training\6\Training_70376763.jpg
# Save image to ../images/realtime/input/Training\6\Training_41869445.jpg
# Save image to ../images/realtime/input/Training\2\Training_10822510.jpg
# Save image to ../images/realtime/input/Training\6\Training_38633482.jpg
# Save image to ../images/realtime/input/Training\4\Training_32175977.jpg
# Save image to ../images/realtime/input/Training\3\Training_98892442.jpg
# Save image to ../images/realtime/input/Training\2\Training_1068498.jpg
# Save image to ../images/realtime/input/Training\4\Training_21252692.jpg
# Save image to ../images/realtime/input/Training\0\Training_15051645.jpg
# Save image to ../images/realtime/input/Training\6\Training_72622960.jpg
# Save image to ../images/realtime/input/Training\3\Training_4945573.jpg
# Save image to ../images/realtime/input/Training\2\Training_63301149.jpg
# Save image to ../images/realtime/input/Training\3\Training_92213910.jpg
# Save image to ../images/realtime/input/Training\0\Training_69173570.jpg
# Save image to ../images/realtime/input/Training\6\Training_19045451.jpg
# Save image to ../images/realtime/input/Training\5\Training_15520732.jpg
# Save image to ../images/realtime/input/Training\0\Training_7504860.jpg
# Save image to ../images/realtime/input/Training\5\Training_41952287.jpg
# Save image to ../images/realtime/input/Training\2\Training_11072482.jpg
# Save image to ../images/realtime/input/Training\6\Training_49762014.jpg
# Save image to ../images/realtime/input/Training\1\Training_4574069.jpg
# Save image to ../images/realtime/input/Training\3\Training_11650248.jpg
# Save image to ../images/realtime/input/Training\2\Training_56965029.jpg
# Save image to ../images/realtime/input/Training\6\Training_20382043.jpg
# Save image to ../images/realtime/input/Training\2\Training_53017613.jpg
# Save image to ../images/realtime/input/Training\0\Training_41599845.jpg
# Save image to ../images/realtime/input/Training\4\Training_57269286.jpg
# Save image to ../images/realtime/input/Training\6\Training_58602068.jpg
# Save image to ../images/realtime/input/Training\4\Training_56539929.jpg
# Save image to ../images/realtime/input/Training\5\Training_11200894.jpg
# Save image to ../images/realtime/input/Training\4\Training_73559916.jpg
# Save image to ../images/realtime/input/Training\4\Training_78874423.jpg
# Save image to ../images/realtime/input/Training\2\Training_81487211.jpg
# Save image to ../images/realtime/input/Training\0\Training_76147888.jpg
# Save image to ../images/realtime/input/Training\4\Training_14030441.jpg
# Save image to ../images/realtime/input/Training\0\Training_26590365.jpg
# Save image to ../images/realtime/input/Training\2\Training_75332805.jpg
# Save image to ../images/realtime/input/Training\0\Training_74502415.jpg
# Save image to ../images/realtime/input/Training\0\Training_33597878.jpg
# Save image to ../images/realtime/input/Training\5\Training_67461357.jpg
# Save image to ../images/realtime/input/Training\3\Training_42832334.jpg
# Save image to ../images/realtime/input/Training\3\Training_35326853.jpg
# Save image to ../images/realtime/input/Training\5\Training_24505024.jpg
# Save image to ../images/realtime/input/Training\3\Training_56520374.jpg
# Save image to ../images/realtime/input/Training\3\Training_14570119.jpg
# Save image to ../images/realtime/input/Training\4\Training_17945766.jpg
# Save image to ../images/realtime/input/Training\6\Training_63962289.jpg
# Save image to ../images/realtime/input/Training\5\Training_90833741.jpg
# Save image to ../images/realtime/input/Training\3\Training_76545526.jpg
# Save image to ../images/realtime/input/Training\3\Training_37174437.jpg
# Save image to ../images/realtime/input/Training\3\Training_62258107.jpg
# Save image to ../images/realtime/input/Training\4\Training_63059213.jpg
# Save image to ../images/realtime/input/Training\4\Training_97538662.jpg
# Save image to ../images/realtime/input/Training\6\Training_44762302.jpg
# Save image to ../images/realtime/input/Training\3\Training_45540008.jpg
# Save image to ../images/realtime/input/Training\4\Training_43331994.jpg
# Save image to ../images/realtime/input/Training\2\Training_37327679.jpg
# Save image to ../images/realtime/input/Training\3\Training_77002252.jpg
# Save image to ../images/realtime/input/Training\2\Training_32921386.jpg
# Save image to ../images/realtime/input/Training\2\Training_59216094.jpg
# Save image to ../images/realtime/input/Training\3\Training_97378289.jpg
# Save image to ../images/realtime/input/Training\4\Training_26375937.jpg
# Save image to ../images/realtime/input/Training\3\Training_74965339.jpg
# Save image to ../images/realtime/input/Training\6\Training_95650888.jpg
# Save image to ../images/realtime/input/Training\2\Training_44899505.jpg
# Save image to ../images/realtime/input/Training\6\Training_24970728.jpg
# Save image to ../images/realtime/input/Training\4\Training_50671416.jpg
# Save image to ../images/realtime/input/Training\3\Training_36389885.jpg
# Save image to ../images/realtime/input/Training\0\Training_17995359.jpg
# Save image to ../images/realtime/input/Training\3\Training_62047578.jpg
# Save image to ../images/realtime/input/Training\4\Training_92341934.jpg
# Save image to ../images/realtime/input/Training\6\Training_65020417.jpg
# Save image to ../images/realtime/input/Training\6\Training_85551874.jpg
# Save image to ../images/realtime/input/Training\0\Training_36925010.jpg
# Save image to ../images/realtime/input/Training\0\Training_95614620.jpg
# Save image to ../images/realtime/input/Training\5\Training_69846621.jpg
# Save image to ../images/realtime/input/Training\3\Training_66277131.jpg
# Save image to ../images/realtime/input/Training\1\Training_10448377.jpg
# Save image to ../images/realtime/input/Training\2\Training_6384021.jpg
# Save image to ../images/realtime/input/Training\4\Training_44939790.jpg
# Save image to ../images/realtime/input/Training\2\Training_2682518.jpg
# Save image to ../images/realtime/input/Training\2\Training_55861389.jpg
# Save image to ../images/realtime/input/Training\3\Training_83703126.jpg
# Save image to ../images/realtime/input/Training\2\Training_57871095.jpg
# Save image to ../images/realtime/input/Training\5\Training_38997698.jpg
# Save image to ../images/realtime/input/Training\0\Training_49220753.jpg
# Save image to ../images/realtime/input/Training\6\Training_28945885.jpg
# Save image to ../images/realtime/input/Training\2\Training_70345698.jpg
# Save image to ../images/realtime/input/Training\4\Training_52482603.jpg
# Save image to ../images/realtime/input/Training\3\Training_11081007.jpg
# Save image to ../images/realtime/input/Training\2\Training_81779962.jpg
# Save image to ../images/realtime/input/Training\3\Training_8777321.jpg
# Save image to ../images/realtime/input/Training\5\Training_36463705.jpg
# Save image to ../images/realtime/input/Training\0\Training_82980681.jpg
# Save image to ../images/realtime/input/Training\6\Training_74037788.jpg
# Save image to ../images/realtime/input/Training\6\Training_54659992.jpg
# Save image to ../images/realtime/input/Training\5\Training_55458498.jpg
# Save image to ../images/realtime/input/Training\6\Training_11890416.jpg
# Save image to ../images/realtime/input/Training\5\Training_67275605.jpg
# Save image to ../images/realtime/input/Training\3\Training_79021921.jpg
# Save image to ../images/realtime/input/Training\0\Training_21135041.jpg
# Save image to ../images/realtime/input/Training\5\Training_8126069.jpg
# Save image to ../images/realtime/input/Training\6\Training_69259959.jpg
# Save image to ../images/realtime/input/Training\0\Training_12978011.jpg
# Save image to ../images/realtime/input/Training\2\Training_96689157.jpg
# Save image to ../images/realtime/input/Training\6\Training_69487302.jpg
# Save image to ../images/realtime/input/Training\6\Training_49890317.jpg
# Save image to ../images/realtime/input/Training\6\Training_1599150.jpg
# Save image to ../images/realtime/input/Training\2\Training_83033293.jpg
# Save image to ../images/realtime/input/Training\4\Training_6526966.jpg
# Save image to ../images/realtime/input/Training\6\Training_50610899.jpg
# Save image to ../images/realtime/input/Training\2\Training_72890851.jpg
# Save image to ../images/realtime/input/Training\6\Training_49997581.jpg
# Save image to ../images/realtime/input/Training\0\Training_11939182.jpg
# Save image to ../images/realtime/input/Training\5\Training_92119006.jpg
# Save image to ../images/realtime/input/Training\3\Training_48511345.jpg
# Save image to ../images/realtime/input/Training\3\Training_50702680.jpg
# Save image to ../images/realtime/input/Training\4\Training_22902906.jpg
# Save image to ../images/realtime/input/Training\4\Training_7169064.jpg
# Save image to ../images/realtime/input/Training\0\Training_69389967.jpg
# Save image to ../images/realtime/input/Training\0\Training_89384830.jpg
# Save image to ../images/realtime/input/Training\2\Training_12588700.jpg
# Save image to ../images/realtime/input/Training\5\Training_49967835.jpg
# Save image to ../images/realtime/input/Training\0\Training_502362.jpg
# Save image to ../images/realtime/input/Training\6\Training_69531756.jpg
# Save image to ../images/realtime/input/Training\0\Training_46789052.jpg
# Save image to ../images/realtime/input/Training\6\Training_57154188.jpg
# Save image to ../images/realtime/input/Training\5\Training_6236401.jpg
# Save image to ../images/realtime/input/Training\4\Training_69135561.jpg
# Save image to ../images/realtime/input/Training\0\Training_52142790.jpg
# Save image to ../images/realtime/input/Training\0\Training_19742844.jpg
# Save image to ../images/realtime/input/Training\3\Training_16740169.jpg
# Save image to ../images/realtime/input/Training\5\Training_32290457.jpg
# Save image to ../images/realtime/input/Training\5\Training_23824412.jpg
# Save image to ../images/realtime/input/Training\4\Training_24086968.jpg
# Save image to ../images/realtime/input/Training\3\Training_31229514.jpg
# Save image to ../images/realtime/input/Training\3\Training_38098615.jpg
# Save image to ../images/realtime/input/Training\1\Training_10389100.jpg
# Save image to ../images/realtime/input/Training\4\Training_63732046.jpg
# Save image to ../images/realtime/input/Training\6\Training_35758343.jpg
# Save image to ../images/realtime/input/Training\6\Training_30348526.jpg
# Save image to ../images/realtime/input/Training\3\Training_77015464.jpg
# Save image to ../images/realtime/input/Training\2\Training_11698338.jpg
# Save image to ../images/realtime/input/Training\3\Training_49848843.jpg
# Save image to ../images/realtime/input/Training\3\Training_4053910.jpg
# Save image to ../images/realtime/input/Training\6\Training_6804147.jpg
# Save image to ../images/realtime/input/Training\6\Training_71157589.jpg
# Save image to ../images/realtime/input/Training\4\Training_61742998.jpg
# Save image to ../images/realtime/input/Training\6\Training_80060373.jpg
# Save image to ../images/realtime/input/Training\0\Training_62675689.jpg
# Save image to ../images/realtime/input/Training\2\Training_93366369.jpg
# Save image to ../images/realtime/input/Training\6\Training_53244892.jpg
# Save image to ../images/realtime/input/Training\5\Training_80751371.jpg
# Save image to ../images/realtime/input/Training\4\Training_8611735.jpg
# Save image to ../images/realtime/input/Training\2\Training_35147736.jpg
# Save image to ../images/realtime/input/Training\6\Training_55594434.jpg
# Save image to ../images/realtime/input/Training\6\Training_69777310.jpg
# Save image to ../images/realtime/input/Training\3\Training_88201441.jpg
# Save image to ../images/realtime/input/Training\5\Training_11438218.jpg
# Save image to ../images/realtime/input/Training\6\Training_51429953.jpg
# Save image to ../images/realtime/input/Training\4\Training_75220065.jpg
# Save image to ../images/realtime/input/Training\6\Training_34931456.jpg
# Save image to ../images/realtime/input/Training\0\Training_41042858.jpg
# Save image to ../images/realtime/input/Training\4\Training_18640898.jpg
# Save image to ../images/realtime/input/Training\2\Training_84879732.jpg
# Save image to ../images/realtime/input/Training\3\Training_75144455.jpg
# Save image to ../images/realtime/input/Training\3\Training_167293.jpg
# Save image to ../images/realtime/input/Training\0\Training_85071548.jpg
# Save image to ../images/realtime/input/Training\0\Training_45953804.jpg
# Save image to ../images/realtime/input/Training\6\Training_65781158.jpg
# Save image to ../images/realtime/input/Training\2\Training_7193570.jpg
# Save image to ../images/realtime/input/Training\6\Training_64585163.jpg
# Save image to ../images/realtime/input/Training\3\Training_81479295.jpg
# Save image to ../images/realtime/input/Training\3\Training_98606346.jpg
# Save image to ../images/realtime/input/Training\6\Training_40180240.jpg
# Save image to ../images/realtime/input/Training\5\Training_61714136.jpg
# Save image to ../images/realtime/input/Training\3\Training_32057729.jpg
# Save image to ../images/realtime/input/Training\1\Training_25429038.jpg
# Save image to ../images/realtime/input/Training\3\Training_39771604.jpg
# Save image to ../images/realtime/input/Training\2\Training_97314207.jpg
# Save image to ../images/realtime/input/Training\2\Training_26803706.jpg
# Save image to ../images/realtime/input/Training\4\Training_44386920.jpg
# Save image to ../images/realtime/input/Training\2\Training_77881656.jpg
# Save image to ../images/realtime/input/Training\2\Training_62440556.jpg
# Save image to ../images/realtime/input/Training\4\Training_65536402.jpg
# Save image to ../images/realtime/input/Training\0\Training_1394967.jpg
# Save image to ../images/realtime/input/Training\3\Training_76985662.jpg
# Save image to ../images/realtime/input/Training\5\Training_54315139.jpg
# Save image to ../images/realtime/input/Training\6\Training_33619518.jpg
# Save image to ../images/realtime/input/Training\3\Training_29321868.jpg
# Save image to ../images/realtime/input/Training\3\Training_60031996.jpg
# Save image to ../images/realtime/input/Training\2\Training_91996219.jpg
# Save image to ../images/realtime/input/Training\3\Training_53701212.jpg
# Save image to ../images/realtime/input/Training\0\Training_51032886.jpg
# Save image to ../images/realtime/input/Training\4\Training_26396080.jpg
# Save image to ../images/realtime/input/Training\2\Training_93872858.jpg
# Save image to ../images/realtime/input/Training\6\Training_96055252.jpg
# Save image to ../images/realtime/input/Training\2\Training_89318028.jpg
# Save image to ../images/realtime/input/Training\3\Training_26006747.jpg
# Save image to ../images/realtime/input/Training\5\Training_83595055.jpg
# Save image to ../images/realtime/input/Training\6\Training_60366725.jpg
# Save image to ../images/realtime/input/Training\2\Training_93751469.jpg
# Save image to ../images/realtime/input/Training\4\Training_55364520.jpg
# Save image to ../images/realtime/input/Training\2\Training_88711239.jpg
# Save image to ../images/realtime/input/Training\2\Training_94648827.jpg
# Save image to ../images/realtime/input/Training\6\Training_59852707.jpg
# Save image to ../images/realtime/input/Training\6\Training_37621104.jpg
# Save image to ../images/realtime/input/Training\4\Training_5476596.jpg
# Save image to ../images/realtime/input/Training\6\Training_43878255.jpg
# Save image to ../images/realtime/input/Training\6\Training_36149813.jpg
# Save image to ../images/realtime/input/Training\3\Training_18990148.jpg
# Save image to ../images/realtime/input/Training\4\Training_39977309.jpg
# Save image to ../images/realtime/input/Training\0\Training_90369138.jpg
# Save image to ../images/realtime/input/Training\3\Training_80766837.jpg
# Save image to ../images/realtime/input/Training\4\Training_19901450.jpg
# Save image to ../images/realtime/input/Training\4\Training_98702494.jpg
# Save image to ../images/realtime/input/Training\0\Training_65276438.jpg
# Save image to ../images/realtime/input/Training\3\Training_54283158.jpg
# Save image to ../images/realtime/input/Training\4\Training_54403617.jpg
# Save image to ../images/realtime/input/Training\6\Training_92934454.jpg
# Save image to ../images/realtime/input/Training\4\Training_27875561.jpg
# Save image to ../images/realtime/input/Training\0\Training_49982297.jpg
# Save image to ../images/realtime/input/Training\4\Training_6751011.jpg
# Save image to ../images/realtime/input/Training\6\Training_91837245.jpg
# Save image to ../images/realtime/input/Training\3\Training_52540097.jpg
# Save image to ../images/realtime/input/Training\5\Training_75919862.jpg
# Save image to ../images/realtime/input/Training\2\Training_10710609.jpg
# Save image to ../images/realtime/input/Training\3\Training_31403420.jpg
# Save image to ../images/realtime/input/Training\0\Training_24873201.jpg
# Save image to ../images/realtime/input/Training\0\Training_85912226.jpg
# Save image to ../images/realtime/input/Training\3\Training_28641307.jpg
# Save image to ../images/realtime/input/Training\6\Training_89680635.jpg
# Save image to ../images/realtime/input/Training\3\Training_67499077.jpg
# Save image to ../images/realtime/input/Training\3\Training_3885504.jpg
# Save image to ../images/realtime/input/Training\6\Training_6106031.jpg
# Save image to ../images/realtime/input/Training\4\Training_26079137.jpg
# Save image to ../images/realtime/input/Training\5\Training_68945187.jpg
# Save image to ../images/realtime/input/Training\0\Training_44637332.jpg
# Save image to ../images/realtime/input/Training\2\Training_11175808.jpg
# Save image to ../images/realtime/input/Training\3\Training_72752289.jpg
# Save image to ../images/realtime/input/Training\0\Training_12659215.jpg
# Save image to ../images/realtime/input/Training\3\Training_52103110.jpg
# Save image to ../images/realtime/input/Training\5\Training_39712213.jpg
# Save image to ../images/realtime/input/Training\3\Training_21814266.jpg
# Save image to ../images/realtime/input/Training\4\Training_26786322.jpg
# Save image to ../images/realtime/input/Training\3\Training_24379251.jpg
# Save image to ../images/realtime/input/Training\4\Training_75354512.jpg
# Save image to ../images/realtime/input/Training\6\Training_92206120.jpg
# Save image to ../images/realtime/input/Training\6\Training_23933917.jpg
# Save image to ../images/realtime/input/Training\3\Training_7290420.jpg
# Save image to ../images/realtime/input/Training\4\Training_63394970.jpg
# Save image to ../images/realtime/input/Training\5\Training_70150489.jpg
# Save image to ../images/realtime/input/Training\3\Training_72990477.jpg
# Save image to ../images/realtime/input/Training\6\Training_48535272.jpg
# Save image to ../images/realtime/input/Training\4\Training_98239520.jpg
# Save image to ../images/realtime/input/Training\6\Training_90235960.jpg
# Save image to ../images/realtime/input/Training\5\Training_47653588.jpg
# Save image to ../images/realtime/input/Training\3\Training_82187022.jpg
# Save image to ../images/realtime/input/Training\0\Training_78543433.jpg
# Save image to ../images/realtime/input/Training\3\Training_36093005.jpg
# Save image to ../images/realtime/input/Training\2\Training_23399239.jpg
# Save image to ../images/realtime/input/Training\3\Training_81419769.jpg
# Save image to ../images/realtime/input/Training\3\Training_22600575.jpg
# Save image to ../images/realtime/input/Training\3\Training_3441145.jpg
# Save image to ../images/realtime/input/Training\5\Training_60365885.jpg
# Save image to ../images/realtime/input/Training\5\Training_67925531.jpg
# Save image to ../images/realtime/input/Training\6\Training_29391704.jpg
# Save image to ../images/realtime/input/Training\2\Training_24084081.jpg
# Save image to ../images/realtime/input/Training\3\Training_58020679.jpg
# Save image to ../images/realtime/input/Training\0\Training_2168882.jpg
# Save image to ../images/realtime/input/Training\3\Training_10545269.jpg
# ...
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_10212029.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_60072046.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_6921059.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_82863811.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_4143757.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_21272748.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_51650283.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_12971205.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_48114382.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_53423205.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_95041706.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_18973030.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_59274835.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_1722799.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_5091676.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_66136742.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_67242834.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_8496978.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_61494171.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_55930288.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_62570706.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_95454180.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_83823000.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_88761234.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_24075947.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_64739731.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_78834033.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_35045984.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_3771850.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_46492285.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_63386629.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_54171306.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_58885063.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_43828660.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_14918702.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_94389871.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_23389299.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_62182426.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_78449729.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_5774.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_38238910.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_23760588.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_43284568.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_25504581.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_75118493.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_11775312.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_11361710.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_58472043.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_63600805.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_46011292.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_31302964.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_89974296.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_7549361.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_30790681.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_68773202.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_28094572.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_57705845.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_17723901.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_38208915.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_56593067.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_55030761.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_72762491.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_10206165.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_58131064.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_17154586.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_92776196.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_50194199.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_62132962.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_49025690.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_52588183.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_64517098.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_9414762.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_22907076.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_62657667.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_67787605.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_70954958.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_63052210.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_95316153.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_27684193.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_30274504.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_3280018.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_63497183.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_45397448.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_2901346.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_36548672.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_94414984.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_94690769.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_20540403.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_98707024.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_60160174.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_54814249.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_63779793.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_69157469.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_34236082.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_56502445.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_92742462.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_30638418.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_84306125.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_13179227.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_66516981.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_32812241.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_83586750.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_54943233.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_38645544.jpg
# Save image to ../images/realtime/input/PrivateTest\1\PrivateTest_19929705.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_95497939.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_26856231.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_85622640.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_84513875.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_8515785.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_89379064.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_75231179.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_4468988.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_1433547.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_56378395.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_4367984.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_66032259.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_64601738.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_98188622.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_26373361.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_69799802.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_23576813.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_99456237.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_64122716.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_734930.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_24326922.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_92387125.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_63386253.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_35667130.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_19293975.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_41770319.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_90954861.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_9558041.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_65006931.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_58382154.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_93646835.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_491225.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_72662111.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_36921211.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_22614532.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_95480912.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_82599596.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_10493325.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_26296766.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_10705248.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_14013067.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_3678788.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_32841072.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_88447346.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_82136256.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_70385618.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_99457306.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_83390153.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_75175430.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_67092205.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_8413934.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_33107244.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_84313462.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_58105969.jpg
# Save image to ../images/realtime/input/PrivateTest\1\PrivateTest_63298725.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_56651918.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_15065503.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_41404472.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_2886853.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_53887877.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_18297307.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_74862768.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_53231006.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_98529546.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_18960009.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_63353270.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_97521781.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_9899009.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_46375319.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_17577514.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_25791648.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_15767853.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_87665379.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_86249448.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_14748065.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_91174328.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_96015157.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_1922505.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_24869326.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_94846665.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_4538576.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_56374646.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_73231532.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_8478957.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_12724087.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_4493608.jpg
# Save image to ../images/realtime/input/PrivateTest\4\PrivateTest_64753466.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_60307677.jpg
# Save image to ../images/realtime/input/PrivateTest\5\PrivateTest_71418823.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_27591527.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_91249212.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_74708951.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_6954668.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_72879581.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_87079611.jpg
# Save image to ../images/realtime/input/PrivateTest\6\PrivateTest_93125226.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_43492861.jpg
# Save image to ../images/realtime/input/PrivateTest\0\PrivateTest_77326777.jpg
# Save image to ../images/realtime/input/PrivateTest\3\PrivateTest_10055852.jpg
# Save image to ../images/realtime/input/PrivateTest\2\PrivateTest_72000480.jpg

# %%
# display some images for every different expression

import numpy as np
import seaborn as sns
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os
# %matplotlib inline
# size of the image: 48*48 pixels
pic_size = 48

# input path for the images
base_path = "../images/realtime/input/"

# %%
# display some images for every different expression

import numpy as np
import seaborn as sns
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os
# %matplotlib inline
# size of the image: 48*48 pixels
pic_size = 48

# input path for the images
base_path = "../images/realtime/input/"

plt.figure(0, figsize=(12,20))
cpt = 0
trainFolder = "training/"
for expression in os.listdir(base_path + trainFolder):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + trainFolder + expression + "/" +os.listdir(base_path + trainFolder + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator

# number of images to feed into the NN for every batch
batch_size = 32

datagen_train = ImageDataGenerator()
datagen_validation = ImageDataGenerator()

train_generator = datagen_train.flow_from_directory(base_path + trainFolder,
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = datagen_validation.flow_from_directory(base_path + "validation",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 57417 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.

# %%
set(train_generator.classes)
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
len(set(train_generator.classes))
# Out:
# 7

# %%
nclasses = len(set(train_generator.classes))

# %%
base_path
# Out:
# '../images/realtime/input/'

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam

# number of possible label values
nb_classes = 7

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(48, 48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\kopo\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\kopo\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', 
           show_shapes=True, 
           show_layer_names=True)
from IPython.display import Image
Image(retina=True, filename='model_plot.png')

# %% [markdown]
# ## Train Model

# %%
# number of epochs to train the NN
epochs = 10

from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# WARNING:tensorflow:From C:\Users\kopo\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 1794/1794 [==============================] - 4132s 2s/step - loss: 1.8286 - acc: 0.2998 - val_loss: 1.5325 - val_acc: 0.4157
#
# Epoch 00001: val_acc improved from -inf to 0.41574, saving model to model_weights.h5
# Epoch 2/10
# 1794/1794 [==============================] - 4132s 2s/step - loss: 1.5359 - acc: 0.4102 - val_loss: 1.4152 - val_acc: 0.4639
#
# Epoch 00002: val_acc improved from 0.41574 to 0.46387, saving model to model_weights.h5
# Epoch 3/10
# 1794/1794 [==============================] - 4157s 2s/step - loss: 1.3769 - acc: 0.4732 - val_loss: 1.2330 - val_acc: 0.5218
#
# Epoch 00003: val_acc improved from 0.46387 to 0.52179, saving model to model_weights.h5
# Epoch 4/10
# 1794/1794 [==============================] - 3945s 2s/step - loss: 1.2719 - acc: 0.5161 - val_loss: 1.1964 - val_acc: 0.5477
#
# Epoch 00004: val_acc improved from 0.52179 to 0.54765, saving model to model_weights.h5
# Epoch 5/10
# 1794/1794 [==============================] - 14930s 8s/step - loss: 1.1966 - acc: 0.5427 - val_loss: 1.1554 - val_acc: 0.5575
#
# Epoch 00005: val_acc improved from 0.54765 to 0.55749, saving model to model_weights.h5
# Epoch 6/10
# 1794/1794 [==============================] - 4290s 2s/step - loss: 1.1298 - acc: 0.5718 - val_loss: 1.1219 - val_acc: 0.5715
#
# Epoch 00006: val_acc improved from 0.55749 to 0.57155, saving model to model_weights.h5
# Epoch 7/10
# 1794/1794 [==============================] - 5336s 3s/step - loss: 1.0775 - acc: 0.5929 - val_loss: 1.0916 - val_acc: 0.5839
#
# Epoch 00007: val_acc improved from 0.57155 to 0.58392, saving model to model_weights.h5
# Epoch 8/10
# 1794/1794 [==============================] - 4495s 3s/step - loss: 1.0235 - acc: 0.6122 - val_loss: 1.0755 - val_acc: 0.6050
#
# Epoch 00008: val_acc improved from 0.58392 to 0.60500, saving model to model_weights.h5
# Epoch 9/10
# 1794/1794 [==============================] - 4135s 2s/step - loss: 0.9757 - acc: 0.6338 - val_loss: 1.1837 - val_acc: 0.5651
#
# Epoch 00009: val_acc did not improve from 0.60500
# Epoch 10/10
# 1794/1794 [==============================] - 4150s 2s/step - loss: 0.9257 - acc: 0.6529 - val_loss: 1.0815 - val_acc: 0.6056
#
# Epoch 00010: val_acc improved from 0.60500 to 0.60557, saving model to model_weights.h5

# %%
# serialize model structure to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

model.save("realtimemodel_all.h5")

model.save_weights("realtimemodel_weight.h5")

# %% [markdown]
# ### 모델 재사용

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
from keras.models import model_from_json 
json_file = open("model.json", "r") 
loaded_model_json = json_file.read() 
json_file.close() 
loaded_model = model_from_json(loaded_model_json)
# Out:
# WARNING:tensorflow:From C:\Users\kopo\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\kopo\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
loaded_model.load_weights("model_weights.h5") 
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
opt = Adam(lr=0.0001)
loaded_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# number of epochs to train the NN
epochs = 2

from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights2.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = loaded_model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# WARNING:tensorflow:From C:\Users\kopo\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/2
# 1794/1794 [==============================] - 4205s 2s/step - loss: 0.8842 - acc: 0.6687 - val_loss: 1.0656 - val_acc: 0.6091
#
# Epoch 00001: val_acc improved from -inf to 0.60910, saving model to model_weights2.h5
# Epoch 2/2
# 1794/1794 [==============================] - 4305s 2s/step - loss: 0.8393 - acc: 0.6865 - val_loss: 1.0669 - val_acc: 0.6207
#
# Epoch 00002: val_acc improved from 0.60910 to 0.62075, saving model to model_weights2.h5

# %%
# serialize model structure to JSON
model_json = loaded_model.to_json()
with open("model2.json", "w") as json_file:
    json_file.write(model_json)

loaded_model.save("realtimemodel_all2.h5")

loaded_model.save_weights("realtimemodel_weight2.h5")

# %%
import cv2
import FacialExpressionModel
import numpy as np

# %%
facec = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
model = FacialExpressionModel.FacialExpressionModel("model.json", "model_weights.h5")
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
class VideoCamera(object):
    def __init__(self):
        self.video = cv2.VideoCapture(0)

    def __del__(self):
        self.video.release()

    # returns camera frames along with bounding boxes and predictions
    def get_frame(self):
        _, fr = self.video.read()
        gray_fr = cv2.cvtColor(fr, cv2.COLOR_BGR2GRAY)
        faces = facec.detectMultiScale(gray_fr, 1.3, 5)

        for (x, y, w, h) in faces:
            fc = gray_fr[y:y+h, x:x+w]

            roi = cv2.resize(fc, (48, 48))
            pred = model.predict_emotion(roi[np.newaxis, :, :, np.newaxis])

            cv2.putText(fr, pred, (x, y), font, 1, (255, 255, 0), 2)
            cv2.rectangle(fr,(x,y),(x+w,y+h),(255,0,0),2)

        _, jpeg = cv2.imencode('.jpg', fr)
        return jpeg.tobytes()

# %%
from flask import Flask, render_template, Response
from camera import VideoCamera

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

def gen(camera):
    while True:
        frame = camera.get_frame()
        yield (b'--frame\r\n'
               b'Content-Type: image/jpeg\r\n\r\n' + frame + b'\r\n\r\n')

@app.route('/video_feed')
def video_feed():
    return Response(gen(VideoCamera()),
                    mimetype='multipart/x-mixed-replace; boundary=frame')

if __name__ == '__main__':
    app.run(host='0.0.0.0', debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\kopo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3304: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
