# %%
import pandas as pd
selloutData=pd.read_csv("./dataset/kopo_channel_seasonality_new.csv")

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine 
import pymysql
# import d6tstack

# %%
engine = create_engine('postgresql://postgres:postgres@192.168.110.111:5432/kopo')

# %%
selloutData.columns=selloutData.columns.str.lower()

# %%
resultname='pgresult'
selloutData.to_sql(name ="pgout",con = engine, index = False ,if_exists = "replace")

# %%
##mysql performance tip
# 옆에 있는 동료의 postgreSQL 서버에 접속 한후
# “kopo_product_volume” 자료를 불러와서
# 컬럼명을 변경 후 자신의 postgreSQL에 저장하세요

# %%
engine = create_engine('mysql+pymysql://sybabo:sybabo@192.168.110.3:3306/test')
engine2 = create_engine('postgresql://postgres:postgres@192.168.110.111:5432/kopo')

# %%
selloutData=pd.read_sql_query('SELECT*FROM sun_young_babo',engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# ProgrammingError: relation "sun_young_babo" does not exist
# LINE 1: SELECT*FROM sun_young_babo
#                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...

# %%
selloutData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0
# 2      A60  PRODUCT34    201402   4463.0
# 3      A60  PRODUCT47    201402      0.0
# 4      A60  PRODUCT56    201402     23.0

# %%
selloutData.to_sql(name ="pgtest222222222",con = engine2, index = False ,if_exists = "replace")

# %%
selloutData=pd.read_csv("./dataset/kopo_channel_seasonality_new.csv")
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK      int64
# QTY         float64
# dtype: object

# %%
### 1.타입전환

# %%
selloutData["YEARWEEK"] = selloutData.YEARWEEK.astype("str")
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK     object
# QTY         float64
# dtype: object

# %%
selloutData.min()
# Out:
# REGIONID         A00
# PRODUCT     PRODUCT1
# YEARWEEK      201401
# QTY             -364
# dtype: object

# %%
####2.행열 조회

# %%
len(selloutData[selloutData.QTY<0])
# Out:
# 323

# %%
selloutData2=selloutData[selloutData.QTY<0]

# %%
###3.데이터 정제

# %%
import numpy as np

# %%
selloutData["NEW_QTY"]=np.where(selloutData.QTY<0,0,selloutData.QTY)

# %%
selloutData[selloutData.QTY>=0][selloutData.QTY == selloutData.NEW_QTY]
# Out:
# C:\Users\SMART-14\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        REGIONID    PRODUCT YEARWEEK       QTY   NEW_QTY
# 0           A60   PRODUCT4   201402      71.0      71.0
# 1           A60  PRODUCT59   201402   22275.0   22275.0
# 2           A60  PRODUCT34   201402    4463.0    4463.0
# 3           A60  PRODUCT47   201402       0.0       0.0
# 4           A60  PRODUCT56   201402      23.0      23.0
# 5           A60  PRODUCT57   201402      14.0      14.0
# 6           A60  PRODUCT12   201402    1186.0    1186.0
# 7           A60   PRODUCT1   201402       7.0       7.0
# 8           A60  PRODUCT33   201402     101.0     101.0
# 9           A60  PRODUCT62   201402     336.0     336.0
# 10          A37  PRODUCT58   201402       0.0       0.0
# 11          A37  PRODUCT59   201402   11492.0   11492.0
# ...

# %%
selloutData["YEAR"]=selloutData.YEARWEEK.str[0:4]
selloutData["WEEK"]=selloutData.YEARWEEK.str[4:6]

# %%
selloutData.min()
# Out:
# REGIONID         A00
# PRODUCT     PRODUCT1
# YEARWEEK      201401
# QTY             -364
# NEW_QTY            0
# YEAR            2014
# WEEK              01
# dtype: object

# %%
selloutData.max()
# Out:
# REGIONID            A77
# PRODUCT        PRODUCT8
# YEARWEEK         201652
# QTY         1.66321e+06
# NEW_QTY     1.66321e+06
# YEAR               2016
# WEEK                 53
# dtype: object

# %%
refinedSelloutData = selloutData[selloutData.WEEK.astype(int) <= 52]

# %%
refinedSelloutData.max()
# Out:
# REGIONID            A77
# PRODUCT        PRODUCT8
# YEARWEEK         201652
# QTY         1.66321e+06
# NEW_QTY     1.66321e+06
# YEAR               2016
# WEEK                 52
# dtype: object

# %%
### 데이터 정렬

# %%
sortKey=["REGIONID","PRODUCT","YEARWEEK"]

# %%
sortedData =refinedSelloutData.sort_values(sortKey)

# %%
groupKey=["REGIONID","PRODUCT"]
gfunction=["mean","std"]
groupData=sortedData.groupby(groupKey)["NEW_QTY"].agg(gfunction).reset_index()

# %%
groupData.rename(columns={"mean":"MEAN","std":"STD"},inplace=True)      ##inplace 중요!!

# %%
groupData.head()
# Out:
#   REGIONID    PRODUCT           MEAN            STD
# 0      A00  PRODUCT34     133.057692     155.176039
# 1      A00  PRODUCT58     105.250000     274.315679
# 2      A00  PRODUCT59   35957.570513   15154.625012
# 3      A01   PRODUCT1    5712.775641    3716.549078
# 4      A01  PRODUCT12  196825.403846  199486.717203

# %%
refinedSelloutData.columns
# Out:
# Index(['REGIONID', 'PRODUCT', 'YEARWEEK', 'QTY', 'NEW_QTY', 'YEAR', 'WEEK'], dtype='object')

# %%
groupData.columns
# Out:
# Index(['REGIONID', 'PRODUCT', 'MEAN', 'STD'], dtype='object')

# %%
joinKey = ["REGIONID","PRODUCT"]

# %%
joindata=pd.merge(refinedSelloutData,groupData,on =joinKey, how ="left")

# %%
reqcolumns = ["REGIONID","PRODUCT","YEARWEEK","YEAR","WEEK","NEW_QTY","MEAN"]

# %%
middleResult=joindata[reqcolumns]

# %%
middleResult["SEASONALITY"]=np.where(middleResult.MEAN !=0, middleResult.NEW_QTY/middleResult.MEAN,0)
# Out:
# C:\Users\SMART-14\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
finalgroupKey=["REGIONID","PRODUCT","WEEK"]
finalResult = middleResult.groupby(finalgroupKey)["SEASONALITY"].agg(["mean"]).reset_index()

# %%
finalResult.rename(columns={"mean":"SEASONALITY"},inplace =True)
seasonMap = finalResult.groupby(finalgroupKey)["SEASONALITY"].agg("mean").to_dict()

# %%
seasonMap
# Out:
# {('A00', 'PRODUCT34', '01'): 2.0868140868140865,
#  ('A00', 'PRODUCT34', '02'): 2.234619646384352,
#  ('A00', 'PRODUCT34', '03'): 1.7736667148431853,
#  ('A00', 'PRODUCT34', '04'): 1.7886977886977886,
#  ('A00', 'PRODUCT34', '05'): 1.5131281013633953,
#  ('A00', 'PRODUCT34', '06'): 1.2876619935443463,
#  ('A00', 'PRODUCT34', '07'): 1.2300428771017005,
#  ('A00', 'PRODUCT34', '08'): 1.0772269595799007,
#  ('A00', 'PRODUCT34', '09'): 1.305198246374717,
#  ('A00', 'PRODUCT34', '10'): 1.5732523967818082,
#  ('A00', 'PRODUCT34', '11'): 1.1849496555378907,
#  ('A00', 'PRODUCT34', '12'): 1.0396492749433925,
#  ('A00', 'PRODUCT34', '13'): 0.9820301585007467,
#  ('A00', 'PRODUCT34', '14'): 0.9795249795249794,
#  ('A00', 'PRODUCT34', '15'): 0.8367297779062484,
#  ('A00', 'PRODUCT34', '16'): 0.8166883461001105,
#  ('A00', 'PRODUCT34', '17'): 0.7265019029724913,
#  ('A00', 'PRODUCT34', '18'): 0.5686756274991568,
#  ('A00', 'PRODUCT34', '19'): 0.5160668690080453,
# ...

# %%
seasonMap["A00","PRODUCT34","01"]
# Out:
# 2.0868140868140865

# %%
("A00","PRODUCT34","01")in seasonMap
# Out:
# True

# %%
groupKey2 = ["REGIONID","PRODUCT"]

# %%
groupData2=sortedData.groupby(groupKey2)

# %%
len(groupData2)
# Out:
# 794

# %%
len(sortedData[["REGIONID","PRODUCT"]].drop_duplicates())    ##drop_duplicates 중복 제거
# Out:
# 794

# %%
oneGroup = groupData2.get_group(list(groupData2.groups)[0])

# %%
len(oneGroup)
# Out:
# 156

# %%
def mafunction(oneGroup,in_window):
    eachData = oneGroup.reset_index(drop=True)

    eachData["MA"] = eachData.NEW_QTY.rolling(window=in_window, center =True, min_periods=1).mean()

    return eachData

# %%
WINDOW = 5

# %%
groupData2=sortedData.groupby(groupKey2).apply(mafunction,(WINDOW))

# %%
emptyColumns= ["REGIONID","PRODUCT","ITME","YEARWEEK","QTY"]

# %%
emptydf=pd.DataFrame(columns=emptyColumns)

# %%
emptydf
# Out:
# Empty DataFrame
# Columns: [REGIONID, PRODUCT, ITME, YEARWEEK, QTY]
# Index: []

# %%
REGIONID ="A00"
PRODUCT ="PRODUCT34"
ITEM="ITEM01"
STARTWEEK ="201925"

# %%
PAST_WINDOW = 4

# %%
from fintechlab import CommonFunction as cf

# %%
for i in range(0, PAST_WINDOW):
    emptydf = emptydf.append(pd.DataFrame([[REGIONID,PRODUCT,ITEM,cf.preWeek(STARTWEEK,i),100+(i*10)]],
                               columns = emptyColumns),
                  ignore_index=True)

# %%
emptydf
# Out:
#   REGIONID    PRODUCT    ITME YEARWEEK  QTY
# 0      A00  PRODUCT34  ITEM01   201925  100
# 1      A00  PRODUCT34  ITEM01   201924  110
# 2      A00  PRODUCT34  ITEM01   201923  120
# 3      A00  PRODUCT34  ITEM01   201922  130

# %%
cf.preWeek("201925",1)
# Out:
# '201924'

# %%
print((seasonMap["A00", "PRODUCT34", "25"]+
seasonMap["A00", "PRODUCT34", "24"]+
seasonMap["A00", "PRODUCT34", "23"]+
seasonMap["A00", "PRODUCT34", "22"])/4)
# Out:
# 0.40897046779399715

# %%
stdQty=emptydf.QTY.mean()
stdQty
# Out:
# 115.0

# %%
weekList=emptydf.YEARWEEK.str[4:6]
seasonList =[]
for i in weekList:
    seasonList.append(seasonMap[REGIONID,PRODUCT,i])
    stdSeasonality = sum(seasonList)/ len(weekList)

# %%
stdSeasonality
# Out:
# 0.40897046779399715

# %%
sum(seasonList)
# Out:
# 1.6358818711759886

# %%
len(weekList)
# Out:
# 4

# %%
FCST_WINDOW =5

# %%
STARTWEEK
# Out:
# '201925'

# %%
for i in range (0,FCST_WINDOW):
    emptydf = emptydf.append(pd.DataFrame([[REGIONID,PRODUCT,ITEM,cf.postWeek(STARTWEEK,i+1),0]],columns=emptyColumns),ignore_index=True)

# %%
emptydf["FCST"]=0
emptydf["AVG_QTY"]=stdQty
emptydf["AVG_SEASON"]=stdSeasonality

# %%
emptydf
# Out:
#   REGIONID    PRODUCT    ITME YEARWEEK  QTY  FCST  AVG_QTY  AVG_SEASON
# 0      A00  PRODUCT34  ITEM01   201925  100     0    115.0     0.40897
# 1      A00  PRODUCT34  ITEM01   201924  110     0    115.0     0.40897
# 2      A00  PRODUCT34  ITEM01   201923  120     0    115.0     0.40897
# 3      A00  PRODUCT34  ITEM01   201922  130     0    115.0     0.40897
# 4      A00  PRODUCT34  ITEM01   201926    0     0    115.0     0.40897
# 5      A00  PRODUCT34  ITEM01   201927    0     0    115.0     0.40897
# 6      A00  PRODUCT34  ITEM01   201928    0     0    115.0     0.40897
# 7      A00  PRODUCT34  ITEM01   201929    0     0    115.0     0.40897
# 8      A00  PRODUCT34  ITEM01   201930    0     0    115.0     0.40897

# %%
def seasonmapping(yearweek):
    week=yearweek[4:6]
    seasonality=seasonMap[REGIONID,PRODUCT,week]
    return seasonality

# %%
emptydf ["SEASONALITY"] = emptydf["YEARWEEK"].apply(seasonmapping)

# %%
emptydf["FCST"] = emptydf.AVG_QTY/emptydf.AVG_SEASON*emptydf.SEASONALITY
### 예측값 최근 한달간 판매량/최근 한달간 계절성 지수 * 예측주차의 계절성 지수

# %%
emptydf
# Out:
#   REGIONID    PRODUCT    ITME YEARWEEK  QTY        FCST  AVG_QTY  AVG_SEASON  \
# 0      A00  PRODUCT34  ITEM01   201925  100   79.601838    115.0     0.40897
# 1      A00  PRODUCT34  ITEM01   201924  110  112.006126    115.0     0.40897
# 2      A00  PRODUCT34  ITEM01   201923  120  123.277182    115.0     0.40897
# 3      A00  PRODUCT34  ITEM01   201922  130  145.114855    115.0     0.40897
# 4      A00  PRODUCT34  ITEM01   201926    0   70.444104    115.0     0.40897
# 5      A00  PRODUCT34  ITEM01   201927    0   86.646248    115.0     0.40897
# 6      A00  PRODUCT34  ITEM01   201928    0  138.774885    115.0     0.40897
# 7      A00  PRODUCT34  ITEM01   201929    0  505.084227    115.0     0.40897
# 8      A00  PRODUCT34  ITEM01   201930    0  395.895865    115.0     0.40897
#
#    SEASONALITY
# 0     0.283085
# 1     0.398323
# 2     0.438406
# 3     0.516067
# 4     0.250518
# 5     0.308137
# 6     0.493520
# 7     1.796213
# 8     1.407911

# %%
qty =[10,100,200]
predict =[20,150,200]
pd.DataFrame(zip(qty,predict))
# Out:
#      0    1
# 0   10   20
# 1  100  150
# 2  200  200
