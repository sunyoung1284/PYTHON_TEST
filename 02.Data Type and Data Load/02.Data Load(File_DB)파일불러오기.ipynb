# %% [markdown]
# ### 1.파일 데이터 불러오기

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\SMART-14\\python_practice\\02.Data Type and Data Load'

# %%
customerData = pd.read_csv("../dataset/kopo_region_mst_hangul.csv", encoding='ms949')
customerData
# Out:
#    REGIONID REGIONNAME
# 0       A00       아프리카
# 1       A01         미국
# 2       A02         한국
# 3       A03         독일
# 4       A04        브라질
# 5       A05         아랍
# 6       A06        앙골라
# 7       A07        벨기에
# 8       A08       불가리아
# 9       A09        바레인
# 10      A10        브라질
# 11      A11       볼리비아
# 12      A12        캐나다
# 13      A13        스위스
# 14      A14         칠레
# 15      A15         중국
# 16      A16       콜롬비아
# 17      A17      코스타리카
# 18      A18        덴마크
# 19      A19        알제리
# 20      A20        이집트
# 21      A21        스페인
# 22      A22        핀란드
# 23      A23        프랑스
# 24      A24         영국
# 25      A25         가나
# 26      A26        그리스
# 27      A27          괌
# 28      A28         홍콩
# 29      A29        아이티
# ..      ...        ...
# 43      A43       네덜런드
# 44      A44        멕시코
# 45      A45         네팔
# 46      A46       뉴질랜드
# 47      A47        필리핀
# 48      A48        폴란드
# 49      A49       포르투갈
# 50      A50       루마니아
# ...

# %%
customerData1 = pd.read_csv("../dataset/customerdata.csv")
customerData1
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
customerData1.columns = ['AVGPRICE','CUSTID','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']
customerData1
# Out:
#     AVGPRICE       CUSTID  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0     A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1     A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2     A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3     A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4     B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5     B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6     B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7     C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8     C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9     C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
# 10    C18306  4005.005142    2          4.7    3.113618      Sleeping-dog
# 11    C18622  3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
customerData.to_csv("../dataset/customerdata_out.csv",index = False ,encoding="ms949")
customerData.head()
# Out:
#   REGIONID REGIONNAME
# 0      A00       아프리카
# 1      A01         미국
# 2      A02         한국
# 3      A03         독일
# 4      A04        브라질

# %%
import pandas as pd

# %%
import pymysql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-8748c87b3097> in <module>()
# ----> 1 import pymysql
#
# ModuleNotFoundError: No module named 'pymysql'
